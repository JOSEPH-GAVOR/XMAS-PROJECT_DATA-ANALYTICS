# %% [markdown]
# ### NAME: JOSEPH GAVOR

# %% [markdown]
# ### INDEX NUMBER: 11115915

# %% [markdown]
# ### CLASS: BIOMEDICAL ENGINEERING

# %% [markdown]
# ### SENG207_PROGRAMMING PROJECT - (DATA ANALYSIS)

# %%
import pandas as pd

# %%
import matplotlib.pyplot  as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head (10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset_new = dataset.dropna()

# %%
dataset_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
mean_FA = dataset['fixed acidity'].mean()
mean_VA = dataset['volatile acidity'].mean()
mean_CA = dataset['citric acid'].mean()
mean_RS = dataset['residual sugar'].mean()
mean_chlorides = dataset['chlorides'].mean()
mean_FSD = dataset['free sulfur dioxide'].mean()
mean_TSD = dataset['total sulfur dioxide'].mean()
mean_density = dataset['density'].mean()
mean_PH = dataset['pH'].mean()
mean_sulphates = dataset['sulphates'].mean()
mean_alcohol = dataset['alcohol'].mean()
mean_quality = dataset['quality'].mean()

# %%
print(f'fixed acidity: {mean_FA}')
print(f'volatile acidity: {mean_VA}')
print(f'citric acid: {mean_CA}')
print(f'residual sugar: {mean_RS}')
print(f'chlorides : {mean_chlorides }')
print(f'free sulfur dioxide: {mean_FSD}')
print(f'total sulfur dioxide: {mean_TSD}')
print(f'density: {mean_density}')
print(f'PH: {mean_PH}')
print(f'sulphates: {mean_sulphates}')
print(f'alcohol: {mean_alcohol}')
print(f'quality: {mean_quality}')
# Out:
# fixed acidity: 8.318335419274094
# volatile acidity: 0.527747183979975
# citric acid: 0.2709756097560976
# residual sugar: 2.53880550343965
# chlorides : 0.08747586206896552
# free sulfur dioxide: 15.867334167709638
# total sulfur dioxide: 46.46779237023139
# density: 0.996745519399249
# PH: 3.3111131957473416
# sulphates: 0.6581488430268917
# alcohol: 10.422983114446529
# quality: 5.635794743429287

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(mean_FA)
dataset['volatile acidity'] =dataset['volatile acidity'].fillna(mean_VA)
dataset['citric acid'] =  dataset['citric acid'].fillna(mean_CA)
dataset['residual sugar'] = dataset['residual sugar'].fillna(mean_RS)
dataset['chlorides'] = dataset['chlorides'].fillna(mean_chlorides)
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(mean_FSD)
dataset['total sulfur dioxide'] = dataset['total sulfur dioxide'].fillna(mean_TSD)
dataset['density'] = dataset['density'].fillna(mean_density)
dataset['pH'] = dataset['pH'].fillna(mean_PH)
dataset['sulphates'] = dataset['sulphates'].fillna(mean_sulphates)
dataset['alcohol'] = dataset['alcohol'].fillna(mean_alcohol )
dataset['quality'] = dataset['quality'].fillna(mean_quality)

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.duplicated ()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
dataset = dataset.drop_duplicates()

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### GRAPHICAL REPRESENTATION OF DATA (DATASET)

# %%
for column in dataset.columns: 
    plt.figure() 
    dataset[column].plot(kind='hist',title=column)
    plt.show()

# %% [markdown]
# ### Exploratory Data Analysis - Histograms
# #### In this analysis, we'll explore the distribution of each feature in a dataset with 1360 rows and 12 columns.
# #### The dataset includes the following columns:
#
# #### - 'fixed acidity'
# #### - 'volatile acidity'
# #### - 'citric acid'
# #### - 'residual sugar'
# #### - 'chlorides'
# #### - 'free sulfur dioxide'
# #### - 'total sulfur dioxide'
# #### - 'density'
# #### - 'pH'
# #### - 'sulphates'
# #### - 'alcohol'
# #### - 'quality'

# %% [markdown]
# ## Data Analysis Report

# %% [markdown]
# ### Fixed Acidity:
#
#
# The histogram of the fixed acidity showa slightly right-skewed distributione
# . This indicates thamostof wines in our dataset have a fixed aciditof y around %
# . However, there are a few wines with a higher fixed acidity, which contributes to the right skew of the distributio
# n the slightly left-skew.

# %% [markdown]
# ### Volatile acidity
#  The histogram of the volatile acidity shows a slightly right-skewed distribution.
#  This indicates that most wines in our dataset have a volatile acidity of around 0.6-0.7.
#  However, there are a few wines with a higher volatile acidity, which contributes to the slightly right skew of the distribution.

# %% [markdown]
# ### Citric acid
#  The histogram of the citric acid shows a right-skewed distribution.
#  This indicates that most wines in our dataset have a citric acid content of 0%.
#  This indicates that most wines have a relatively low citric acid content.

# %% [markdown]
# ### Residual Sugar
#  The histogram of the residual sugar shows a right-skewed distribution.
#  This indicates that most wines in our dataset have a residual sugar of around 1-2.
#  This indicates that most wines have a relatively low residual sugar content.

# %% [markdown]
# ### Chlorides
# The chlorides histogram shows a nearly right-skewed distribution. This indicates that most wines in our dataset have a chloride content of 0.1.
# This indicates that most wines have a relatively low chloride content.

# %% [markdown]
# ### Free Sulfur dioxide
# The histogram of the free sulfur dioxide shows a right-skewed distribution.
# This indicates that most wines in our dataset have a free sulfur dioxide content of 0-10.
# A clear indication of relatively low free sulfur dioxide content.

# %% [markdown]
# ### Total sulfur dioxide
# The histogram of the total sulfur dioxide shows a right-skewed distribution. This indicates that most wines in our dataset have a total sulfur dioxide content of 25.
# This indicates that most wines have a relatively low total sulfur dioxide content.

# %% [markdown]
# ### Density
# The density histogram shows a nearly normal distribution with a slight right skew.
# This indicates that the majority of wine in our dataset have a density of 0.996.

# %% [markdown]
# ### pH
# The pH histogram presents a nearly normal distribution. This suggests that most wines have a pH of around 3.3.
# This is within the expected range, as wine is typically slightly acidic.

# %% [markdown]
# ### Sulphates
# The sulphates histogram is right-skewed. This indicates that most wines have a relatively low sulphate content.
# However, there are a few exceptions with higher sulphate content, represented by the long tail on the right side of the distribution.

# %% [markdown]
# ### Alcohol Content
# The histogram of the alcohol content shows a slightly right-skewed distribution.
# This indicates that most wines in our dataset have an alcohol content of around 9%-10%.
# However, there are a few wines with a higher alcohol content, which contributes to the right skew of the distribution.

# %% [markdown]
# ### Quality
# The histogram for wine quality shows a nearly normal distribution with a slight left skew.
# This however shows that the majority of wines in our dataset have a quality of 5 with a few with a higher quality of 6 contributing to the slightly left-skew.

# %% [markdown]
# ### CORRELATION BETWEEN MODIFIED DATASET VALUES

# %%
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.253679     0.666754
# volatile acidity          -0.253679          1.000000    -0.550037
# citric acid                0.666754         -0.550037     1.000000
# residual sugar             0.110855         -0.002313     0.143677
# chlorides                  0.085835          0.054840     0.209866
# free sulfur dioxide       -0.139707         -0.020591    -0.047983
# total sulfur dioxide      -0.102660          0.072334     0.047944
# density                    0.669677          0.024102     0.359296
# pH                        -0.685521          0.247132    -0.548681
# sulphates                  0.190178         -0.256904     0.325422
# alcohol                   -0.061216         -0.197714     0.104459
# quality                    0.119190         -0.395077     0.226920
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### OTHER GRAPHICAL REPRESENTATION OF NUMERICAL DATA (DATASET)

# %%
graph = dataset[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']]

# %%
plt.plot(graph)

# %%
# Create a histogram
plt.hist(dataset, bins=100, edgecolor='blue')

# Add labels and title 
plt.xlabel('columns ')
plt.ylabel('Frequency')
plt.title(' Histogram ')

# Show the plot
plt.show()
